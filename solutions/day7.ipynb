# %% [markdown]
# ## Day 7: Handy Haversacks
#
# You land at the regional airport in time for your next flight. In fact, it looks like you'll even have time to grab some food: all flights are currently delayed due to issues in luggage processing.
#
# Due to recent aviation regulations, many rules (your puzzle input) are being enforced about bags and their contents; bags must be color-coded and must contain specific quantities of other color-coded bags. Apparently, nobody responsible for these regulations considered how long they would take to enforce!
#
# For example, consider the following rules:
#
# ```
# light red bags contain 1 bright white bag, 2 muted yellow bags.
# dark orange bags contain 3 bright white bags, 4 muted yellow bags.
# bright white bags contain 1 shiny gold bag.
# muted yellow bags contain 2 shiny gold bags, 9 faded blue bags.
# shiny gold bags contain 1 dark olive bag, 2 vibrant plum bags.
# dark olive bags contain 3 faded blue bags, 4 dotted black bags.
# vibrant plum bags contain 5 faded blue bags, 6 dotted black bags.
# faded blue bags contain no other bags.
# dotted black bags contain no other bags.
# ```
# These rules specify the required contents for 9 bag types. In this example, every faded blue bag is empty, every vibrant plum bag contains
# 11 bags (5 faded blue and 6 dotted black), and so on.
#
# You have a shiny gold bag. If you wanted to carry it in at least one other bag, how many different bag colors would be valid for the outermost bag?
# (In other words: how many colors can, eventually, contain at least one shiny gold bag?)
#
# In the above rules, the following options would be available to you:
#
# A bright white bag, which can hold your shiny gold bag directly.
# A muted yellow bag, which can hold your shiny gold bag directly, plus some other bags.
# A dark orange bag, which can hold bright white and muted yellow bags, either of which could then hold your shiny gold bag.
# A light red bag, which can hold bright white and muted yellow bags, either of which could then hold your shiny gold bag.
# So, in this example, the number of bag colors that can eventually contain at least one shiny gold bag is 4.
#
# How many bag colors can eventually contain at least one shiny gold bag? (The list of rules is quite long; make sure you get all of it.)

# %%
import re
bags = list(map(str, open('../data/day7_input.txt', 'r').read().split('\n')))

# %%
# Let's set up an empty dictionary for the rules. This is going to be a dictionary that for each key contains the string of the color of the outer bag and each
# value contains a dictionary with that bag's contents. Each of those dictionaries is a key, value pair with color, and number of bags.

set_of_rules = {}

# now let's go through the rules. Note that each bag is going to contain multiple bags, so we'll have nested dictionaries.

for bag in bags:
    outer_bag = re.findall('([\w ]*) bags contain ', bag)[0] # color of the outer bag
    set_of_rules[outer_bag] = {}
    inner_bags = re.findall('(\d+) ([\w ]*) bag(?:s)?', bag) # number and color of inner bags. we'll add these to the inner dictionary we created above.
    for bag in inner_bags:
        set_of_rules[outer_bag][bag[1]] = int(bag[0]) # Use the two capture groups here. The second element of the inner_bag capture group is the color.

# %% [markdown]
# ## Some testing

# %%
bags[0:3]
# Out:
# ['clear purple bags contain 5 faded indigo bags, 3 muted purple bags.',
#  'bright teal bags contain 4 striped plum bags.',
#  'dim fuchsia bags contain 2 vibrant tomato bags, 2 dotted purple bags, 2 plaid indigo bags.']

# %%
re.findall('(\d+) ([\w ]*) bag(?:s)?', bags[0])
# Out:
# [('5', 'faded indigo'), ('3', 'muted purple')]

# %%
set_of_rules
# Out:
# {'clear purple': {'faded indigo': 5, 'muted purple': 3},
#  'bright teal': {'striped plum': 4},
#  'dim fuchsia': {'vibrant tomato': 2, 'dotted purple': 2, 'plaid indigo': 2},
#  'dark magenta': {'shiny aqua': 1, 'posh white': 2},
#  'dark chartreuse': {'dotted brown': 1, 'vibrant magenta': 4},
#  'wavy crimson': {'pale coral': 5},
#  'drab cyan': {'light green': 1, 'pale teal': 2},
#  'posh salmon': {'wavy maroon': 5, 'shiny coral': 5},
#  'light violet': {'faded teal': 5,
#   'light gray': 1,
#   'bright turquoise': 4,
#   'posh crimson': 5},
#  'dark turquoise': {'clear yellow': 1, 'wavy maroon': 1, 'muted brown': 3},
#  'bright coral': {'mirrored silver': 5, 'light teal': 4},
#  'dotted lavender': {'clear indigo': 1},
#  'striped white': {'dull beige': 5},
#  'dotted lime': {'mirrored magenta': 5, 'faded red': 4},
#  'dark tan': {'bright coral': 5, 'wavy salmon': 5, 'posh green': 4},
#  'dull black': {'shiny brown': 2,
#   'plaid bronze': 3,
#   'wavy teal': 3,
#   'dull chartreuse': 3},
#  'wavy coral': {'clear maroon': 5, 'dotted tan': 3},
#  'dotted yellow': {'shiny green': 1, 'mirrored tomato': 1, 'light bronze': 5},
#  'striped tan': {'pale lime': 3},
#  'striped aqua': {'pale magenta': 5, 'drab magenta': 4, 'dotted violet': 2},
#  'drab crimson': {'posh aqua': 4, 'dim gray': 4},
#  'bright indigo': {'striped violet': 5, 'muted orange': 1},
#  'striped yellow': {'mirrored orange': 3, 'clear black': 3, 'pale magenta': 1},
#  'dim teal': {'drab gold': 1},
#  'light green': {'drab magenta': 4, 'dark orange': 3},
#  'posh white': {'clear teal': 1, 'shiny cyan': 3},
#  'wavy fuchsia': {'vibrant magenta': 5, 'dull maroon': 2, 'faded lime': 4},
#  'faded gold': {'shiny indigo': 3, 'light lime': 4},
#  'dotted violet': {'faded tomato': 4,
#   'shiny gold': 3,
#   'faded brown': 4,
#   'clear bronze': 2},
#  'posh olive': {'pale bronze': 2},
#  'mirrored salmon': {'dim crimson': 3, 'striped plum': 5, 'clear plum': 5},
#  'mirrored olive': {'bright orange': 4,
#   'dim silver': 5,
#   'wavy tan': 1,
#   'striped crimson': 5},
#  'shiny orange': {'dim lime': 2, 'plaid lavender': 4, 'dull indigo': 5},
#  'dark fuchsia': {'dull red': 4, 'dotted fuchsia': 1},
#  'wavy white': {'plaid tomato': 5,
#   'wavy indigo': 5,
#   'mirrored brown': 5,
#   'muted red': 3},
#  'plaid violet': {'faded beige': 2, 'muted gold': 2, 'posh brown': 4},
#  'light orange': {'light tomato': 2, 'clear plum': 3},
#  'shiny tan': {'plaid tan': 5, 'wavy red': 2, 'wavy green': 1},
#  'dim gold': {'dull orange': 1},
#  'dark gold': {'pale cyan': 1,
#   'dotted beige': 5,
#   'vibrant teal': 3,
#   'vibrant magenta': 1},
#  'striped tomato': {'faded white': 3,
#   'shiny beige': 4,
#   'bright violet': 1,
#   'plaid aqua': 4},
#  'shiny magenta': {'dark purple': 5, 'dotted green': 1, 'shiny tomato': 2},
#  'plaid tomato': {'bright coral': 4, 'clear teal': 1},
#  'pale turquoise': {'muted gold': 3,
#   'dark bronze': 3,
#   'dotted violet': 5,
#   'light tomato': 5},
#  'shiny silver': {'pale purple': 5, 'muted maroon': 1},
#  'drab brown': {'dotted yellow': 3,
#   'wavy maroon': 3,
#   'striped gold': 3,
#   'faded aqua': 1},
#  'striped olive': {'bright crimson': 5,
#   'dim olive': 5,
#   'pale coral': 2,
#   'dull orange': 2},
#  'plaid gray': {'dim yellow': 2, 'faded lime': 5},
#  'striped violet': {'shiny gray': 5, 'dim lime': 1},
#  'wavy chartreuse': {'striped magenta': 3,
#   'muted crimson': 4,
#   'clear maroon': 5},
#  'plaid salmon': {'bright black': 2},
#  'mirrored teal': {'vibrant crimson': 1,
#   'plaid magenta': 5,
#   'muted green': 2,
#   'wavy brown': 4},
#  'drab yellow': {'posh salmon': 2, 'light purple': 3, 'striped orange': 3},
#  'bright purple': {'muted gold': 5, 'dull olive': 3, 'faded violet': 5},
#  'dim magenta': {'dark olive': 5,
#   'shiny indigo': 2,
#   'shiny turquoise': 5,
#   'dark tan': 5},
#  'wavy violet': {'clear white': 5, 'posh coral': 5},
#  'wavy blue': {'pale chartreuse': 4, 'shiny brown': 2},
#  'plaid crimson': {'faded black': 4},
#  'vibrant tomato': {'posh tomato': 3, 'mirrored silver': 2, 'dotted brown': 5},
#  'clear indigo': {'wavy indigo': 1},
#  'mirrored fuchsia': {'vibrant coral': 2,
#   'clear tan': 5,
#   'pale indigo': 2,
#   'drab bronze': 1},
#  'light silver': {'pale plum': 5, 'clear black': 5, 'pale red': 1},
#  'dim tan': {'pale plum': 1},
#  'pale salmon': {'dim lime': 4},
#  'light lime': {'bright fuchsia': 1, 'bright olive': 1},
#  'dim red': {'clear silver': 5},
#  'striped chartreuse': {'dim chartreuse': 5, 'pale cyan': 3},
#  'bright gray': {'posh teal': 2, 'dark turquoise': 1, 'light yellow': 4},
#  'wavy gold': {'drab white': 5,
#   'wavy salmon': 2,
#   'dim lime': 5,
#   'plaid tomato': 4},
#  'pale maroon': {'vibrant magenta': 3,
#   'dim maroon': 5,
#   'dull aqua': 4,
#   'bright coral': 5},
#  'shiny aqua': {'dotted brown': 5},
#  'dark tomato': {'dull violet': 5, 'vibrant magenta': 1, 'muted brown': 3},
#  'faded aqua': {'bright fuchsia': 1, 'dotted violet': 5, 'shiny gold': 4},
#  'dark plum': {'dull aqua': 5, 'faded red': 3},
#  'plaid aqua': {'drab gold': 3, 'faded tomato': 3, 'plaid cyan': 5},
#  'faded teal': {'vibrant beige': 1, 'posh crimson': 5},
#  'muted coral': {'dim plum': 1, 'wavy salmon': 1, 'plaid cyan': 5},
#  'posh gray': {'posh tomato': 3},
#  'plaid black': {'faded aqua': 4},
#  'wavy gray': {'shiny blue': 1},
#  'shiny maroon': {'wavy crimson': 2, 'dotted coral': 1, 'bright tan': 3},
#  'mirrored lime': {'plaid purple': 5},
#  'dotted chartreuse': {'light salmon': 5},
#  'vibrant gold': {'plaid purple': 5, 'bright olive': 3, 'vibrant yellow': 5},
#  'wavy yellow': {'light tomato': 3},
#  'drab violet': {'light violet': 2,
#   'vibrant tomato': 1,
#   'dim bronze': 3,
#   'striped lavender': 5},
#  'pale lime': {'striped blue': 3, 'shiny indigo': 3, 'posh gold': 5},
#  'light lavender': {'faded chartreuse': 2, 'dim lime': 3, 'faded brown': 4},
#  'mirrored chartreuse': {'dotted violet': 5, 'faded brown': 2},
#  'clear beige': {'faded violet': 4,
#   'clear white': 3,
#   'plaid indigo': 5,
#   'wavy indigo': 2},
#  'dull lime': {'plaid black': 4, 'pale bronze': 5, 'bright plum': 1},
#  'muted violet': {'drab white': 4, 'muted silver': 4, 'dotted bronze': 4},
#  'faded white': {'plaid olive': 4},
#  'striped teal': {'drab crimson': 2,
#   'clear maroon': 3,
#   'muted blue': 4,
#   'posh green': 2},
#  'dull teal': {'wavy yellow': 5},
#  'wavy maroon': {'mirrored salmon': 2,
#   'light teal': 2,
#   'posh gray': 5,
#   'muted olive': 3},
#  'vibrant salmon': {'light turquoise': 3,
#   'striped maroon': 4,
#   'mirrored white': 3,
#   'bright olive': 2},
#  'striped green': {'faded gray': 5, 'pale green': 2, 'posh blue': 4},
#  'posh tan': {'clear salmon': 4},
#  'wavy green': {'vibrant plum': 1,
#   'muted crimson': 1,
#   'light teal': 4,
#   'mirrored salmon': 2},
#  'dotted white': {'plaid teal': 3, 'shiny indigo': 1},
#  'muted tomato': {'pale gray': 4,
#   'wavy red': 5,
#   'dark violet': 5,
#   'posh aqua': 3},
#  'drab beige': {'wavy aqua': 5},
#  'pale purple': {'striped black': 4, 'light turquoise': 1},
#  'muted indigo': {'dim gold': 5, 'dull turquoise': 2, 'dotted olive': 4},
#  'pale coral': {'vibrant beige': 2},
#  'dark beige': {'pale turquoise': 5},
#  'posh crimson': {'dark aqua': 5, 'posh teal': 3, 'dull aqua': 5},
#  'dim purple': {'drab crimson': 5, 'pale aqua': 3, 'clear orange': 5},
#  'shiny teal': {'shiny tan': 4, 'striped salmon': 2, 'drab lime': 5},
#  'muted crimson': {},
#  'plaid green': {'pale bronze': 3},
#  'dim aqua': {'light lime': 2, 'posh green': 4, 'clear white': 5},
#  'plaid lavender': {'striped lime': 2},
#  'dark olive': {'drab magenta': 1, 'bright magenta': 1, 'plaid crimson': 2},
#  'striped crimson': {'vibrant white': 2,
#   'pale bronze': 1,
#   'striped blue': 2,
#   'pale coral': 4},
#  'striped lime': {'shiny gold': 3, 'muted coral': 1, 'dotted red': 3},
#  'plaid silver': {'drab aqua': 2, 'striped orange': 2, 'plaid crimson': 2},
#  'dotted tan': {'light purple': 3,
#   'clear teal': 1,
#   'dotted crimson': 5,
#   'dim lime': 2},
#  'clear blue': {'dotted green': 5, 'drab crimson': 5, 'wavy tomato': 2},
#  'muted green': {'clear maroon': 3, 'dull orange': 5},
#  'dull blue': {'light silver': 3},
#  'striped purple': {'vibrant tomato': 4,
#   'dark bronze': 1,
#   'mirrored white': 1},
#  'light salmon': {'muted coral': 3,
#   'mirrored yellow': 1,
#   'faded red': 4,
#   'muted silver': 3},
#  'wavy black': {'clear indigo': 5,
#   'dotted purple': 4,
#   'posh violet': 3,
#   'bright magenta': 4},
#  'mirrored crimson': {'muted gray': 3, 'drab chartreuse': 5},
#  'vibrant bronze': {'mirrored turquoise': 1,
#   'dull crimson': 3,
#   'faded purple': 3,
#   'dotted beige': 5},
#  'pale teal': {'clear green': 5},
#  'muted red': {'dim plum': 3, 'clear bronze': 3},
#  'mirrored aqua': {'posh aqua': 2,
#   'plaid tomato': 1,
#   'mirrored magenta': 1,
#   'dim chartreuse': 4},
#  'dim yellow': {'bright fuchsia': 5, 'drab tan': 5, 'dark blue': 1},
#  'vibrant green': {'dull aqua': 3, 'posh cyan': 2},
#  'mirrored black': {'striped gray': 2},
#  'striped turquoise': {'shiny gold': 1, 'shiny turquoise': 4},
#  'wavy plum': {'pale brown': 4, 'dark plum': 4, 'bright lavender': 1},
#  'dotted purple': {'dim maroon': 2},
#  'posh teal': {'clear plum': 1, 'faded black': 4, 'dim crimson': 1},
#  'shiny crimson': {'faded red': 1},
#  'mirrored beige': {'faded bronze': 1},
#  'dotted olive': {'pale plum': 5, 'muted plum': 4},
#  'bright lime': {'faded beige': 3,
#   'wavy fuchsia': 3,
#   'vibrant plum': 3,
#   'shiny coral': 3},
#  'pale bronze': {'faded crimson': 5, 'vibrant tan': 4, 'pale coral': 2},
#  'dim coral': {'drab maroon': 5,
#   'striped violet': 4,
#   'plaid crimson': 1,
#   'dim white': 2},
#  'bright violet': {'clear white': 5, 'plaid beige': 1},
#  'plaid gold': {'striped maroon': 2},
#  'dull red': {'wavy tomato': 4, 'clear beige': 5},
#  'muted tan': {'pale beige': 3,
#   'dotted beige': 4,
#   'dull cyan': 5,
#   'striped gold': 1},
#  'posh plum': {'vibrant purple': 3,
#   'light tomato': 2,
#   'drab maroon': 3,
#   'plaid tomato': 3},
#  'dotted gold': {'posh violet': 1, 'dim purple': 4, 'shiny tomato': 3},
#  'posh black': {'muted olive': 1, 'striped turquoise': 5, 'wavy crimson': 1},
#  'shiny beige': {'dull teal': 2,
#   'striped lavender': 3,
#   'vibrant indigo': 3,
#   'mirrored magenta': 3},
#  'posh silver': {'wavy black': 1},
#  'dotted bronze': {'dim plum': 3,
#   'posh gray': 1,
#   'mirrored crimson': 5,
#   'mirrored lime': 5},
#  'pale indigo': {'wavy black': 2, 'shiny aqua': 4, 'striped lime': 1},
#  'muted olive': {'faded brown': 4,
#   'muted gold': 1,
#   'faded teal': 1,
#   'vibrant orange': 2},
#  'shiny white': {'wavy purple': 2},
#  'bright yellow': {'dotted gray': 5, 'clear indigo': 5, 'clear turquoise': 2},
#  'pale tan': {'dotted purple': 5,
#   'vibrant white': 1,
#   'pale red': 3,
#   'mirrored yellow': 3},
#  'drab gray': {'dotted maroon': 5,
#   'shiny fuchsia': 3,
#   'dim lime': 5,
#   'mirrored brown': 3},
#  'drab blue': {'striped purple': 4, 'plaid tomato': 3},
#  'posh indigo': {'muted blue': 3},
#  'dotted turquoise': {'vibrant plum': 1, 'clear gray': 5, 'wavy yellow': 2},
#  'light red': {'muted silver': 2, 'drab chartreuse': 5, 'wavy cyan': 4},
#  'drab red': {'dotted tomato': 3,
#   'dotted plum': 3,
#   'drab orange': 5,
#   'wavy teal': 4},
#  'dotted beige': {'light violet': 5},
#  'clear gray': {'shiny gold': 3,
#   'dull orange': 3,
#   'light fuchsia': 5,
#   'vibrant beige': 5},
#  'vibrant beige': {'drab magenta': 2,
#   'dim maroon': 5,
#   'bright turquoise': 3,
#   'dim plum': 3},
#  'dark brown': {'striped cyan': 2, 'vibrant yellow': 5},
#  'bright blue': {'vibrant lime': 4,
#   'faded yellow': 4,
#   'clear orange': 1,
#   'wavy gray': 4},
#  'dull plum': {'mirrored salmon': 3},
#  'striped gold': {'faded teal': 1, 'vibrant plum': 4},
#  'dotted gray': {'faded black': 1, 'pale tomato': 1},
#  'plaid olive': {'clear gray': 2, 'dotted tan': 5},
#  'faded plum': {'light turquoise': 4,
#   'dim brown': 1,
#   'shiny turquoise': 3,
#   'posh chartreuse': 1},
#  'clear turquoise': {'bright coral': 2, 'drab cyan': 3},
#  'wavy brown': {'clear yellow': 5, 'dim silver': 5, 'mirrored white': 1},
#  'muted maroon': {'posh aqua': 3,
#   'drab yellow': 2,
#   'pale crimson': 3,
#   'dotted maroon': 1},
#  'clear plum': {},
#  'dim silver': {'bright fuchsia': 1},
#  'dotted silver': {'dotted indigo': 2, 'faded chartreuse': 2, 'wavy white': 3},
#  'vibrant olive': {'posh coral': 3, 'drab aqua': 3},
#  'faded yellow': {'plaid tomato': 1, 'light tomato': 1},
#  'drab lavender': {'light gray': 3, 'dotted beige': 3, 'dull tomato': 4},
#  'drab tomato': {'wavy aqua': 4,
#   'posh teal': 1,
#   'clear red': 5,
#   'clear plum': 4},
#  'pale beige': {'wavy salmon': 5},
#  'pale magenta': {'bright fuchsia': 5},
#  'dotted black': {'mirrored lime': 3},
#  'bright plum': {'vibrant teal': 5},
#  'bright lavender': {'dotted purple': 5, 'faded black': 1, 'light purple': 4},
#  'muted yellow': {'dotted aqua': 4, 'dim cyan': 1},
#  'shiny tomato': {'dim crimson': 1},
#  'dotted magenta': {'clear maroon': 2, 'plaid gold': 5},
#  'dull aqua': {'shiny blue': 2},
#  'faded silver': {'faded brown': 4, 'muted brown': 1},
#  'muted gray': {'light yellow': 2,
#   'mirrored brown': 5,
#   'bright teal': 3,
#   'posh teal': 5},
#  'mirrored gold': {'shiny black': 4,
#   'shiny coral': 5,
#   'clear orange': 2,
#   'mirrored aqua': 4},
#  'plaid teal': {'dull orange': 4,
#   'shiny gold': 2,
#   'plaid crimson': 2,
#   'clear green': 4},
#  'light white': {'vibrant white': 5, 'posh lavender': 1, 'clear white': 3},
#  'shiny turquoise': {'bright turquoise': 3},
#  'muted orange': {'bright tan': 1, 'shiny teal': 1, 'bright gold': 5},
#  'mirrored bronze': {'drab white': 2, 'clear bronze': 4, 'drab blue': 3},
#  'shiny green': {'mirrored cyan': 4},
#  'posh tomato': {'dull orange': 3, 'clear plum': 2},
#  'shiny salmon': {'vibrant tomato': 2, 'muted olive': 3, 'dim bronze': 2},
#  'muted purple': {'shiny turquoise': 4},
#  'dim lime': {'posh teal': 3},
#  'muted chartreuse': {'dotted fuchsia': 1, 'light teal': 4, 'dull salmon': 4},
#  'mirrored yellow': {'wavy brown': 4},
#  'drab teal': {'mirrored maroon': 1,
#   'faded fuchsia': 1,
#   'bright coral': 3,
#   'dull purple': 2},
#  'plaid plum': {'dark cyan': 4},
#  'dim indigo': {'dotted gold': 3, 'muted coral': 5, 'posh plum': 2},
#  'wavy aqua': {'drab gold': 4, 'wavy yellow': 5},
#  'vibrant brown': {'posh violet': 3, 'pale magenta': 4},
#  'faded maroon': {'dull maroon': 4,
#   'light indigo': 4,
#   'wavy beige': 4,
#   'clear olive': 1},
#  'light crimson': {'dim gray': 1},
#  'plaid orange': {'plaid bronze': 5, 'dark orange': 1},
#  'clear gold': {'plaid black': 5, 'faded coral': 4},
#  'mirrored gray': {'shiny coral': 1, 'pale beige': 3, 'dark tan': 1},
#  'dark gray': {'dim turquoise': 4, 'clear gray': 3},
#  'light fuchsia': {'dotted brown': 3, 'clear maroon': 3},
#  'posh cyan': {'dotted violet': 2},
#  'light cyan': {'drab maroon': 2,
#   'vibrant indigo': 5,
#   'dull tomato': 3,
#   'wavy gray': 3},
#  'wavy olive': {'wavy cyan': 5, 'mirrored tomato': 4},
#  'faded indigo': {'bright bronze': 4, 'dim lime': 5},
#  'muted plum': {'clear maroon': 1},
#  'muted brown': {'posh gray': 2},
#  'pale tomato': {'dull cyan': 3, 'faded beige': 3},
#  'striped blue': {'faded tomato': 1, 'dotted purple': 3},
#  'dotted fuchsia': {'posh green': 2, 'faded aqua': 1},
#  'vibrant fuchsia': {'mirrored white': 3},
#  'pale cyan': {'dotted green': 3, 'drab maroon': 3},
#  'wavy silver': {'vibrant yellow': 1,
#   'mirrored chartreuse': 5,
#   'drab magenta': 1,
#   'faded tan': 2},
#  'vibrant black': {'dotted purple': 3, 'bright coral': 3},
#  'dull bronze': {'dull white': 5, 'dark olive': 4},
#  'wavy purple': {'dim lavender': 2,
#   'striped red': 5,
#   'posh yellow': 4,
#   'dotted fuchsia': 1},
#  'dim salmon': {'vibrant magenta': 3,
#   'wavy fuchsia': 4,
#   'plaid fuchsia': 1,
#   'dim magenta': 2},
#  'dim orange': {'muted lime': 2},
#  'plaid fuchsia': {'vibrant crimson': 1,
#   'dotted beige': 1,
#   'wavy gray': 5,
#   'dim bronze': 1},
#  'dark black': {'posh lavender': 2, 'light black': 4, 'bright orange': 5},
#  'muted teal': {'clear red': 5, 'vibrant magenta': 4, 'vibrant aqua': 1},
#  'mirrored lavender': {'faded bronze': 1,
#   'bright violet': 2,
#   'dull turquoise': 4},
#  'dark lavender': {'dotted gold': 5, 'dark turquoise': 2, 'dark brown': 1},
#  'dull brown': {'faded brown': 2,
#   'dotted lime': 3,
#   'dull plum': 5,
#   'dull white': 3},
#  'pale gray': {'pale salmon': 1, 'dotted fuchsia': 5},
#  'light coral': {'bright magenta': 2, 'wavy brown': 1},
#  'dull tan': {'shiny turquoise': 5, 'light cyan': 5, 'faded indigo': 2},
#  'dim bronze': {'striped blue': 5},
#  'bright tomato': {'striped black': 1},
#  'shiny chartreuse': {'plaid aqua': 4,
#   'striped tomato': 1,
#   'striped black': 3,
#   'dull maroon': 4},
#  'mirrored silver': {'shiny blue': 4,
#   'dotted maroon': 4,
#   'clear maroon': 3,
#   'clear plum': 4},
#  'pale olive': {'drab brown': 5,
#   'bright lime': 1,
#   'vibrant lime': 1,
#   'muted blue': 3},
#  'pale gold': {'mirrored chartreuse': 1, 'posh silver': 4},
#  'plaid indigo': {'bright fuchsia': 1, 'wavy indigo': 1, 'dark aqua': 5},
#  'mirrored green': {'mirrored crimson': 4, 'dull turquoise': 2},
#  'shiny fuchsia': {'wavy crimson': 4},
#  'drab salmon': {'faded silver': 1, 'muted white': 4, 'clear yellow': 4},
#  'bright salmon': {'bright crimson': 4, 'muted tomato': 1},
#  'posh chartreuse': {'posh cyan': 3, 'plaid cyan': 4},
#  'wavy cyan': {'vibrant magenta': 1, 'posh crimson': 2},
#  'shiny indigo': {'plaid teal': 1},
#  'shiny purple': {'dark purple': 1, 'dull magenta': 5, 'plaid fuchsia': 3},
#  'bright gold': {'faded aqua': 3},
#  'vibrant yellow': {'vibrant brown': 3,
#   'wavy green': 3,
#   'dotted brown': 5,
#   'striped plum': 5},
#  'muted beige': {'vibrant tomato': 4, 'dull fuchsia': 3},
#  'dim maroon': {},
#  'mirrored tan': {'pale turquoise': 3, 'muted olive': 3, 'shiny violet': 3},
#  'striped gray': {'mirrored gold': 5},
#  'drab purple': {'wavy orange': 1},
#  'dull silver': {'clear chartreuse': 4,
#   'posh cyan': 4,
#   'pale salmon': 2,
#   'shiny lavender': 3},
#  'dim blue': {'clear turquoise': 1, 'clear orange': 1, 'clear teal': 4},
#  'dull maroon': {'striped plum': 2},
#  'posh magenta': {'dim gray': 4},
#  'light beige': {'dotted turquoise': 4, 'pale cyan': 1},
#  'dim olive': {'plaid teal': 3, 'faded brown': 5, 'faded crimson': 1},
#  'light tomato': {},
#  'drab black': {'wavy brown': 2,
#   'dull maroon': 1,
#   'muted crimson': 5,
#   'posh green': 3},
#  'posh coral': {'drab gray': 1, 'striped red': 1},
#  'mirrored cyan': {'drab gray': 4},
#  'dotted salmon': {'striped coral': 4, 'muted purple': 2},
#  'bright maroon': {'faded crimson': 1, 'clear maroon': 4, 'faded brown': 2},
#  'light turquoise': {'shiny lime': 2,
#   'dotted violet': 5,
#   'vibrant tan': 3,
#   'shiny cyan': 5},
#  'faded black': {'drab magenta': 4, 'dim plum': 3, 'bright fuchsia': 5},
#  'vibrant silver': {'clear violet': 2,
#   'drab orange': 2,
#   'plaid magenta': 5,
#   'shiny violet': 5},
#  'vibrant tan': {'clear bronze': 3, 'vibrant tomato': 5, 'light teal': 4},
#  'clear bronze': {'posh green': 1, 'faded brown': 4, 'shiny violet': 1},
#  'striped salmon': {'dark fuchsia': 2, 'shiny chartreuse': 4},
#  'wavy indigo': {},
#  'dark violet': {'dull violet': 5, 'wavy tomato': 3, 'pale green': 5},
#  'drab magenta': {'wavy indigo': 4,
#   'dark aqua': 2,
#   'dotted brown': 4,
#   'muted crimson': 2},
#  'dark orange': {'faded violet': 3, 'shiny coral': 3, 'light violet': 4},
#  'drab green': {'light tan': 1, 'plaid tomato': 2},
#  'mirrored magenta': {'vibrant plum': 4, 'vibrant black': 4},
#  'muted cyan': {'dull aqua': 1, 'dark cyan': 3},
#  'dim plum': {'wavy yellow': 2, 'bright fuchsia': 3},
#  'dark bronze': {'shiny violet': 2, 'clear plum': 2},
#  'striped coral': {'shiny coral': 3},
#  'faded violet': {'plaid indigo': 4},
#  'posh brown': {'posh magenta': 5, 'bright fuchsia': 5, 'vibrant plum': 1},
#  'drab coral': {'vibrant beige': 5},
#  'plaid tan': {'dark orange': 5, 'dotted tan': 5},
#  'dark silver': {'pale plum': 1, 'bright cyan': 5, 'wavy aqua': 3},
#  'dark lime': {'drab green': 3, 'light crimson': 5},
#  'dull salmon': {'dull maroon': 3, 'striped gold': 5, 'dotted maroon': 2},
#  'bright white': {'pale teal': 5,
#   'posh white': 2,
#   'bright crimson': 2,
#   'pale fuchsia': 3},
#  'vibrant violet': {'dim brown': 5,
#   'bright brown': 2,
#   'pale coral': 2,
#   'wavy plum': 1},
#  'vibrant magenta': {'clear maroon': 2, 'wavy indigo': 3, 'plaid bronze': 5},
#  'faded coral': {'vibrant maroon': 5, 'mirrored beige': 3},
#  'dark teal': {'dark tan': 1, 'posh chartreuse': 2},
#  'dark crimson': {'dark fuchsia': 2, 'striped blue': 5},
#  'dull yellow': {'faded bronze': 1,
#   'dark beige': 4,
#   'plaid black': 5,
#   'posh salmon': 1},
#  'plaid magenta': {'plaid beige': 1, 'posh teal': 2},
#  'pale chartreuse': {'plaid orange': 1, 'vibrant beige': 2, 'muted gold': 5},
#  'posh lavender': {'plaid violet': 3,
#   'dark blue': 4,
#   'wavy teal': 2,
#   'vibrant black': 5},
#  'dull purple': {'posh lime': 2,
#   'wavy olive': 1,
#   'striped red': 1,
#   'pale lime': 5},
#  'bright tan': {'shiny tan': 2, 'clear green': 4, 'light violet': 1},
#  'pale plum': {'dull crimson': 4, 'vibrant orange': 2, 'striped cyan': 2},
#  'clear crimson': {'mirrored silver': 3},
#  'light blue': {'dull magenta': 5,
#   'clear black': 4,
#   'bright tan': 2,
#   'dotted teal': 1},
#  'muted turquoise': {'bright red': 3,
#   'light tomato': 3,
#   'dull gold': 3,
#   'clear cyan': 4},
#  'muted lime': {'dim olive': 5, 'pale fuchsia': 3},
#  'clear green': {'dim maroon': 5,
#   'bright fuchsia': 4,
#   'muted crimson': 1,
#   'shiny blue': 1},
#  'dim green': {'pale turquoise': 2},
#  'plaid red': {'plaid silver': 3},
#  'mirrored brown': {'clear plum': 1},
#  'dull lavender': {'clear teal': 1},
#  'shiny brown': {'shiny coral': 5,
#   'posh black': 1,
#   'dotted maroon': 2,
#   'muted olive': 2},
#  'dotted green': {'clear crimson': 2,
#   'dim gray': 2,
#   'plaid green': 1,
#   'dotted maroon': 1},
#  'vibrant maroon': {'mirrored brown': 2, 'shiny coral': 5},
#  'dotted tomato': {'wavy coral': 3, 'dotted crimson': 3},
#  'vibrant turquoise': {'posh tomato': 5, 'faded bronze': 2},
#  'bright aqua': {'light tan': 4},
#  'clear teal': {'mirrored salmon': 1, 'dark aqua': 4},
#  'shiny gray': {'mirrored crimson': 3, 'drab chartreuse': 4},
#  'muted black': {'wavy orange': 4},
#  'posh yellow': {'plaid teal': 4},
#  'pale black': {'wavy brown': 5, 'mirrored yellow': 1},
#  'dark red': {'striped magenta': 5, 'plaid salmon': 5},
#  'dull magenta': {'light white': 2,
#   'mirrored blue': 3,
#   'faded black': 3,
#   'shiny coral': 5},
#  'mirrored orange': {'posh white': 5},
#  'dark salmon': {'posh fuchsia': 2},
#  'bright brown': {'posh blue': 4, 'shiny brown': 3},
#  'drab lime': {'dotted maroon': 4, 'pale bronze': 3, 'striped black': 2},
#  'dull violet': {'bright lavender': 5, 'shiny coral': 1},
#  'muted silver': {'muted coral': 1},
#  'dull olive': {'pale cyan': 4, 'drab green': 5, 'clear turquoise': 4},
#  'light aqua': {'posh orange': 4, 'dull fuchsia': 4},
#  'vibrant coral': {'clear bronze': 1, 'striped brown': 3},
#  'muted magenta': {'clear fuchsia': 1,
#   'shiny crimson': 5,
#   'shiny gold': 4,
#   'plaid cyan': 2},
#  'faded blue': {'plaid green': 5},
#  'clear cyan': {'drab cyan': 3},
#  'wavy beige': {'mirrored white': 4,
#   'bright white': 4,
#   'dark beige': 5,
#   'pale tomato': 5},
#  'light maroon': {'vibrant maroon': 3, 'dark orange': 1, 'drab plum': 3},
#  'faded green': {'vibrant black': 1},
#  'vibrant teal': {'shiny violet': 4},
#  'clear coral': {'dark maroon': 4, 'striped tomato': 1, 'light orange': 4},
#  'pale lavender': {'light green': 4, 'drab magenta': 2},
#  'muted blue': {'pale cyan': 5, 'posh teal': 4},
#  'mirrored plum': {'drab aqua': 5, 'striped gold': 3},
#  'dull chartreuse': {'dull orange': 1, 'clear chartreuse': 5},
#  'faded magenta': {'bright blue': 4},
#  'dim cyan': {'muted brown': 1, 'posh magenta': 3},
#  'dim beige': {'shiny blue': 3, 'dim black': 4},
#  'faded tomato': {'vibrant magenta': 1, 'plaid cyan': 2, 'muted crimson': 4},
#  'clear aqua': {'dull bronze': 1, 'shiny bronze': 4},
#  'pale fuchsia': {'mirrored orange': 2},
#  'drab olive': {'wavy salmon': 3},
#  'clear white': {'vibrant teal': 1, 'posh tomato': 1, 'vibrant aqua': 5},
#  'drab orange': {'striped gold': 3,
#   'mirrored tan': 2,
#   'dull tomato': 3,
#   'wavy aqua': 2},
#  'plaid purple': {'dotted maroon': 3, 'shiny turquoise': 5},
#  'mirrored violet': {'clear white': 4, 'shiny black': 2},
#  'dotted teal': {'dim teal': 2, 'striped fuchsia': 1},
#  'bright beige': {'dim silver': 2, 'dull beige': 3},
#  'dim turquoise': {'plaid silver': 1,
#   'light yellow': 1,
#   'shiny orange': 2,
#   'striped cyan': 3},
#  'dotted brown': {},
#  'drab maroon': {'clear plum': 4, 'shiny coral': 4},
#  'dark indigo': {'mirrored magenta': 1},
#  'posh bronze': {'bright bronze': 3,
#   'dotted maroon': 4,
#   'wavy tomato': 3,
#   'dotted lime': 4},
#  'vibrant cyan': {'wavy brown': 5},
#  'drab turquoise': {'muted silver': 2, 'bright maroon': 2, 'dim gray': 5},
#  'pale red': {'shiny coral': 1, 'mirrored silver': 5, 'shiny turquoise': 3},
#  'vibrant lime': {'light lavender': 4, 'mirrored tomato': 4},
#  'dim black': {'light beige': 2,
#   'plaid cyan': 1,
#   'posh yellow': 2,
#   'vibrant cyan': 3},
#  'dull coral': {'dull orange': 5, 'dotted green': 1},
#  'posh violet': {'light green': 5, 'pale teal': 3},
#  'bright silver': {'wavy white': 5, 'vibrant salmon': 2},
#  'light plum': {'light indigo': 4, 'posh gold': 1},
#  'plaid coral': {'dark olive': 4},
#  'bright magenta': {'bright fuchsia': 1,
#   'dim crimson': 4,
#   'clear yellow': 2,
#   'bright lavender': 2},
#  'striped lavender': {'dull orange': 4},
#  'drab aqua': {'vibrant tan': 4, 'vibrant crimson': 3, 'dotted purple': 1},
#  'shiny blue': {'plaid bronze': 2},
#  'wavy lime': {'drab orange': 2},
#  'dull white': {'light teal': 4},
#  'pale orange': {'plaid yellow': 2, 'posh indigo': 1},
#  'faded chartreuse': {'dull tomato': 4, 'mirrored salmon': 3},
#  'bright orange': {'vibrant yellow': 4,
#   'vibrant salmon': 4,
#   'faded white': 3,
#   'clear orange': 4},
#  'dark blue': {'vibrant indigo': 3},
#  'striped indigo': {'vibrant magenta': 3},
#  'mirrored blue': {'bright crimson': 5, 'light salmon': 5, 'dark olive': 5},
#  'plaid chartreuse': {'drab tomato': 5,
#   'dark tan': 1,
#   'dotted crimson': 4,
#   'dark bronze': 5},
#  'shiny cyan': {'shiny aqua': 1,
#   'clear plum': 5,
#   'posh gray': 1,
#   'shiny coral': 5},
#  'dim violet': {'drab chartreuse': 3, 'pale lavender': 4, 'shiny gold': 5},
#  'dotted orange': {'plaid chartreuse': 5, 'vibrant purple': 4, 'posh teal': 5},
#  'clear magenta': {'clear indigo': 3},
#  'vibrant chartreuse': {'faded violet': 4},
#  'dark cyan': {'dim plum': 2,
#   'light purple': 5,
#   'dark olive': 1,
#   'dim maroon': 2},
#  'light olive': {'pale lime': 5, 'mirrored lime': 2},
#  'vibrant lavender': {'pale black': 2},
#  'plaid maroon': {'clear white': 4},
#  'pale aqua': {'shiny tomato': 2, 'dim gold': 4, 'pale green': 5},
#  'posh blue': {'wavy fuchsia': 1, 'light cyan': 3, 'striped beige': 1},
#  'clear lime': {'mirrored gold': 4, 'wavy coral': 2},
#  'pale yellow': {'dull cyan': 2,
#   'dotted maroon': 1,
#   'light teal': 3,
#   'clear gray': 1},
#  'muted lavender': {'wavy cyan': 1},
#  'light magenta': {'shiny lime': 5, 'light indigo': 3, 'clear beige': 2},
#  'dotted maroon': {'wavy yellow': 4, 'bright fuchsia': 5, 'faded brown': 5},
#  'shiny red': {'faded tomato': 2,
#   'faded black': 3,
#   'pale teal': 2,
#   'muted bronze': 5},
#  'shiny lavender': {'bright yellow': 1,
#   'plaid purple': 2,
#   'light coral': 2,
#   'pale purple': 4},
#  'clear violet': {'plaid chartreuse': 1},
#  'muted white': {'striped turquoise': 1},
#  'plaid bronze': {},
#  'faded fuchsia': {'clear red': 5},
#  'dull orange': {'drab gold': 5,
#   'dotted purple': 2,
#   'bright turquoise': 4,
#   'plaid bronze': 4},
#  'clear red': {'clear crimson': 4, 'bright turquoise': 3, 'clear green': 3},
#  'vibrant aqua': {'light gray': 5,
#   'light tomato': 3,
#   'vibrant white': 5,
#   'posh tomato': 5},
#  'drab bronze': {'striped fuchsia': 3,
#   'vibrant coral': 3,
#   'posh turquoise': 3,
#   'clear maroon': 5},
#  'dotted crimson': {'muted teal': 4, 'dull violet': 5, 'muted gold': 2},
#  'mirrored purple': {'drab black': 5, 'dotted teal': 1},
#  'dark aqua': {},
#  'light tan': {'dotted tan': 5},
#  'wavy turquoise': {'mirrored cyan': 2,
#   'mirrored magenta': 4,
#   'dull salmon': 5,
#   'vibrant tomato': 2},
#  'light black': {'clear plum': 5, 'faded olive': 5},
#  'vibrant blue': {'dark crimson': 4, 'clear indigo': 2, 'pale lime': 2},
#  'clear silver': {'striped coral': 1,
#   'faded crimson': 5,
#   'mirrored chartreuse': 5,
#   'vibrant magenta': 2},
#  'shiny gold': {'plaid bronze': 5,
#   'bright fuchsia': 4,
#   'light violet': 2,
#   'clear plum': 1},
#  'bright red': {'pale coral': 2},
#  'dull tomato': {'mirrored salmon': 3},
#  'clear fuchsia': {'bright brown': 3},
#  'faded orange': {'clear plum': 4, 'faded maroon': 5},
#  'clear black': {'plaid aqua': 2,
#   'faded yellow': 2,
#   'bright magenta': 2,
#   'striped blue': 5},
#  'drab white': {'muted olive': 1, 'posh magenta': 5, 'plaid tan': 3},
#  'wavy salmon': {'clear maroon': 1},
#  'shiny yellow': {'bright magenta': 2},
#  'shiny lime': {'shiny turquoise': 4,
#   'mirrored white': 2,
#   'faded bronze': 4,
#   'vibrant white': 1},
#  'clear yellow': {'shiny violet': 5,
#   'light tomato': 4,
#   'clear plum': 3,
#   'wavy indigo': 1},
#  'wavy red': {'dim crimson': 2, 'plaid cyan': 5},
#  'dotted red': {'dim plum': 5},
#  'faded red': {'striped maroon': 3},
#  'muted gold': {'vibrant teal': 1, 'faded crimson': 3},
#  'dotted aqua': {'dotted coral': 2, 'faded maroon': 4},
#  'vibrant purple': {'posh aqua': 3, 'light gray': 2},
#  'faded salmon': {'plaid brown': 5, 'drab white': 4, 'wavy olive': 5},
#  'light chartreuse': {'shiny coral': 4, 'shiny purple': 2},
#  'dim brown': {'clear bronze': 5, 'striped orange': 2, 'dark olive': 5},
#  'striped black': {'dark orange': 1, 'faded red': 4},
#  'dark white': {'clear white': 5,
#   'dull bronze': 2,
#   'dull chartreuse': 5,
#   'dark crimson': 3},
#  'striped brown': {'shiny indigo': 1, 'vibrant black': 1},
#  'bright olive': {'striped black': 4, 'dull violet': 3, 'vibrant orange': 3},
#  'dull green': {'dotted orange': 4,
#   'dotted coral': 5,
#   'pale tan': 5,
#   'faded beige': 1},
#  'faded bronze': {'shiny blue': 3},
#  'faded tan': {'pale bronze': 2},
#  'plaid cyan': {'clear maroon': 4,
#   'dark aqua': 5,
#   'bright fuchsia': 1,
#   'plaid bronze': 2},
#  'striped bronze': {'vibrant silver': 1, 'dim red': 1, 'vibrant maroon': 3},
#  'dotted blue': {'vibrant tan': 2},
#  'drab gold': {'dim crimson': 2, 'faded tomato': 3, 'drab magenta': 2},
#  'faded cyan': {'dotted lavender': 3,
#   'mirrored plum': 4,
#   'plaid olive': 2,
#   'muted lime': 1},
#  'dark green': {'dim crimson': 5,
#   'vibrant aqua': 4,
#   'pale beige': 1,
#   'faded aqua': 5},
#  'posh green': {'dim maroon': 4, 'faded black': 3, 'wavy yellow': 5},
#  'pale brown': {'dull coral': 3},
#  'light yellow': {'vibrant black': 5},
#  'mirrored coral': {'wavy teal': 1,
#   'plaid gold': 5,
#   'muted crimson': 4,
#   'clear teal': 3},
#  'plaid blue': {'vibrant tomato': 2,
#   'light fuchsia': 3,
#   'shiny tomato': 1,
#   'faded red': 1},
#  'light gold': {'plaid chartreuse': 1, 'plaid tan': 3},
#  'light brown': {'light green': 4, 'shiny orange': 1},
#  'light gray': {'drab magenta': 3},
#  'wavy teal': {'drab tan': 2},
#  'drab tan': {'light tomato': 5,
#   'muted tan': 3,
#   'shiny blue': 3,
#   'dull white': 1},
#  'plaid beige': {'muted crimson': 5, 'faded white': 5, 'dull aqua': 5},
#  'striped fuchsia': {'dim plum': 5,
#   'faded gray': 1,
#   'pale turquoise': 2,
#   'dull teal': 3},
#  'vibrant red': {'dim aqua': 3, 'plaid green': 5},
#  'faded crimson': {'faded brown': 3},
#  'muted aqua': {'muted purple': 5, 'drab tan': 5, 'shiny magenta': 2},
#  'pale blue': {'pale lavender': 4},
#  'wavy tomato': {'striped plum': 2,
#   'dull aqua': 4,
#   'light tan': 3,
#   'pale black': 4},
#  'drab fuchsia': {'muted purple': 2,
#   'striped lime': 2,
#   'clear white': 4,
#   'bright turquoise': 1},
#  'dim crimson': {'light tomato': 3,
#   'muted crimson': 5,
#   'plaid bronze': 4,
#   'faded tomato': 2},
#  'faded turquoise': {'posh yellow': 5, 'plaid chartreuse': 3},
#  'vibrant indigo': {'bright turquoise': 5},
#  'mirrored turquoise': {'light lavender': 4,
#   'wavy turquoise': 2,
#   'wavy red': 2},
#  'posh turquoise': {'posh crimson': 4},
#  'vibrant white': {'dotted purple': 2,
#   'faded teal': 5,
#   'faded tomato': 4,
#   'dull aqua': 5},
#  'faded olive': {'bright bronze': 4, 'vibrant purple': 2, 'dotted violet': 3},
#  'posh orange': {'light green': 4, 'vibrant white': 5, 'shiny lime': 1},
#  'pale violet': {'drab indigo': 3},
#  'dotted indigo': {'bright coral': 5, 'plaid purple': 3},
#  'clear tan': {'dim plum': 4, 'vibrant purple': 5},
#  'vibrant orange': {'striped plum': 3},
#  'shiny violet': {'plaid cyan': 5, 'striped plum': 5},
#  'striped silver': {'clear yellow': 1, 'dotted green': 3},
#  'bright chartreuse': {'wavy tomato': 5, 'bright yellow': 2},
#  'vibrant plum': {'wavy yellow': 3, 'dim maroon': 5, 'plaid bronze': 5},
#  'clear maroon': {},
#  'wavy orange': {'plaid aqua': 3, 'pale salmon': 1},
#  'wavy bronze': {'drab green': 5, 'dim plum': 3, 'mirrored lavender': 4},
#  'light indigo': {'dark aqua': 5},
#  'shiny bronze': {'vibrant magenta': 4, 'clear teal': 2, 'muted coral': 4},
#  'posh aqua': {'dotted green': 2, 'bright plum': 4, 'vibrant orange': 1},
#  'striped maroon': {'dotted beige': 5, 'light tomato': 5},
#  'bright crimson': {'vibrant beige': 5, 'faded teal': 3, 'mirrored white': 5},
#  'pale green': {'bright beige': 4,
#   'posh turquoise': 2,
#   'mirrored silver': 3,
#   'dim lime': 5},
#  'shiny black': {'faded yellow': 1},
#  'plaid brown': {'shiny salmon': 4, 'pale bronze': 2, 'dark orange': 3},
#  'dim lavender': {'dotted tan': 5,
#   'dull maroon': 4,
#   'striped plum': 4,
#   'light purple': 5},
#  'dim gray': {'faded tomato': 2},
#  'dotted plum': {'light gray': 4, 'bright turquoise': 1, 'drab maroon': 2},
#  'faded purple': {'vibrant cyan': 3, 'shiny aqua': 3},
#  'drab plum': {'pale chartreuse': 5, 'wavy crimson': 1},
#  'muted salmon': {'pale orange': 3, 'faded yellow': 4, 'dim tomato': 3},
#  'posh gold': {'drab chartreuse': 2},
#  'light teal': {'clear green': 2,
#   'light violet': 2,
#   'clear yellow': 1,
#   'bright turquoise': 3},
#  'clear tomato': {'posh aqua': 1,
#   'bright beige': 1,
#   'pale coral': 5,
#   'mirrored crimson': 3},
#  'dull turquoise': {'plaid coral': 2},
#  'striped red': {'dotted green': 1, 'plaid olive': 2, 'clear crimson': 1},
#  'shiny plum': {'light indigo': 4, 'muted plum': 4},
#  'dull indigo': {'posh white': 3,
#   'posh green': 1,
#   'dull plum': 1,
#   'shiny black': 5},
#  'dotted coral': {'mirrored magenta': 1, 'bright maroon': 2, 'drab tomato': 1},
#  'drab indigo': {'dotted turquoise': 1},
#  'posh red': {'faded blue': 4, 'mirrored green': 2},
#  'wavy tan': {'shiny cyan': 3,
#   'striped gold': 1,
#   'dim silver': 2,
#   'plaid magenta': 3},
#  'dim chartreuse': {'clear bronze': 2},
#  'vibrant crimson': {'faded brown': 3, 'pale chartreuse': 2},
#  'plaid yellow': {'striped brown': 3, 'plaid white': 1, 'vibrant indigo': 4},
#  'posh fuchsia': {'faded bronze': 5, 'drab gray': 3},
#  'mirrored red': {'wavy lime': 3, 'bright tan': 4, 'faded white': 5},
#  'shiny coral': {'wavy yellow': 4, 'bright turquoise': 2},
#  'dull beige': {'posh aqua': 3},
#  'posh beige': {'pale maroon': 1, 'shiny teal': 4, 'clear lime': 1},
#  'posh maroon': {'muted olive': 1,
#   'dim black': 2,
#   'plaid cyan': 1,
#   'dim olive': 3},
#  'faded gray': {'vibrant tomato': 1, 'posh teal': 4, 'striped maroon': 5},
#  'dotted cyan': {'dull orange': 4, 'clear bronze': 2, 'posh gray': 4},
#  'bright green': {'posh tomato': 5, 'wavy red': 2},
#  'clear lavender': {'dark plum': 3,
#   'dim salmon': 5,
#   'mirrored magenta': 2,
#   'plaid silver': 3},
#  'muted fuchsia': {'pale cyan': 5},
#  'dark yellow': {'plaid orange': 3, 'pale lime': 5, 'pale red': 2},
#  'bright turquoise': {'wavy yellow': 2},
#  'light bronze': {'light purple': 4},
#  'clear orange': {'dotted purple': 3, 'plaid fuchsia': 4, 'shiny lime': 1},
#  'striped orange': {'striped red': 4, 'dark bronze': 1},
#  'clear brown': {'light lavender': 3, 'dim plum': 1, 'shiny gray': 5},
#  'wavy lavender': {'pale gray': 1, 'wavy white': 2, 'bright white': 3},
#  'bright bronze': {'shiny turquoise': 2, 'vibrant indigo': 1},
#  'dull cyan': {'plaid orange': 5,
#   'muted coral': 4,
#   'bright coral': 2,
#   'dark olive': 2},
#  'faded lime': {'faded yellow': 4, 'dim lavender': 1},
#  'shiny olive': {'muted olive': 1,
#   'mirrored turquoise': 4,
#   'plaid magenta': 3},
#  'mirrored tomato': {'wavy green': 1, 'dotted brown': 1, 'posh magenta': 5},
#  'striped cyan': {'dim teal': 2,
#   'bright bronze': 3,
#   'drab chartreuse': 3,
#   'posh salmon': 4},
#  'striped magenta': {'dark orange': 2},
#  'pale white': {'pale indigo': 1},
#  'striped plum': {'dim plum': 3, 'faded black': 4, 'faded brown': 1},
#  'faded brown': {'clear maroon': 4},
#  'mirrored indigo': {'wavy indigo': 2, 'dull fuchsia': 2, 'bright coral': 5},
#  'dark coral': {'dotted fuchsia': 5},
#  'dull fuchsia': {'pale turquoise': 5, 'dark purple': 5, 'light red': 4},
#  'clear chartreuse': {'dotted turquoise': 5},
#  'vibrant gray': {'plaid orange': 3, 'dotted teal': 2},
#  'bright fuchsia': {},
#  'clear salmon': {'light lime': 4,
#   'muted black': 1,
#   'vibrant magenta': 4,
#   'drab yellow': 1},
#  'muted bronze': {'dull aqua': 3, 'striped turquoise': 4},
#  'striped beige': {'vibrant beige': 3},
#  'dim white': {'mirrored blue': 1,
#   'vibrant cyan': 1,
#   'plaid coral': 1,
#   'light yellow': 5},
#  'clear olive': {'faded teal': 2, 'vibrant orange': 1, 'dim bronze': 4},
#  'light purple': {'dull aqua': 4,
#   'light gray': 1,
#   'clear green': 2,
#   'light fuchsia': 4},
#  'mirrored white': {'faded tomato': 3, 'plaid cyan': 5, 'drab magenta': 2},
#  'drab silver': {'dim plum': 2,
#   'wavy yellow': 5,
#   'dull teal': 2,
#   'bright crimson': 3},
#  'dark maroon': {'mirrored purple': 5, 'light tomato': 5},
#  'posh lime': {'light indigo': 2, 'muted tan': 3, 'shiny coral': 3},
#  'pale crimson': {'dotted tan': 2},
#  'plaid turquoise': {'clear teal': 4,
#   'light lavender': 1,
#   'posh salmon': 1,
#   'light teal': 5},
#  'plaid lime': {'wavy gray': 5,
#   'dull magenta': 5,
#   'wavy yellow': 3,
#   'dim aqua': 1},
#  'pale silver': {'mirrored turquoise': 4},
#  'dull gold': {'mirrored gold': 3, 'vibrant purple': 5, 'light beige': 3},
#  'dark purple': {'wavy yellow': 5},
#  'faded lavender': {'posh bronze': 5,
#   'vibrant violet': 2,
#   'drab maroon': 5,
#   'wavy bronze': 3},
#  'dull crimson': {'muted red': 3, 'muted brown': 3},
#  'bright cyan': {'mirrored chartreuse': 3, 'light fuchsia': 5, 'light tan': 2},
#  'drab chartreuse': {'muted green': 5, 'drab olive': 1, 'clear beige': 4},
#  'dull gray': {'posh fuchsia': 5},
#  'bright black': {'faded brown': 5, 'dim aqua': 3, 'bright violet': 4},
#  'faded beige': {'bright teal': 5, 'faded crimson': 4, 'plaid teal': 3},
#  'posh purple': {'shiny purple': 3, 'plaid turquoise': 3},
#  'plaid white': {'dotted cyan': 1},
#  'wavy magenta': {'vibrant tan': 3, 'posh brown': 4, 'bright tan': 4},
#  'dim tomato': {'drab lime': 3, 'vibrant tomato': 4},
#  'mirrored maroon': {'drab coral': 3}}

# %%
re.findall('([\w ]*) bags contain ', bags[0])
# Out:
# ['clear purple']

# %%
# These dictionaries within dictionaries and how they index and iterate is tripping me up.

test_dict = {'hi': {'hola': 1, 'salaam': 2}, 'bye': {'adios': 1, 'khoda hafez': 2}}
for rule in test_dict:
    print(rule)
# Out:
# hi
# bye

# %%
def test_function():
    count = 0
    print(f'initial count is {count}')
    for rule in test_dict:
        for translation in test_dict[rule]:
            print(f'{translation} and the count went up by {test_dict[rule][translation]}')
            count += test_dict[rule][translation]
    print(f'final count is {count}')

# %%
test_function()
# Out:
# initial count is 0
# hola and the count went up by 1
# salaam and the count went up by 2
# adios and the count went up by 1
# khoda hafez and the count went up by 2
# final count is 6

# %%
set_of_rules['shiny gold'] is bool
# Out:
# False

# %% [markdown]
# ## Back to work

# %%
# Here, we've got to make a function that checks the outer bag and sees whether it contains our bag of interest, 'shiny gold' in it.
# If it does, return True. Additionally, we need to keep track of which bags we have already checked for shiny gold. I'm thinking
# we can create an empty list in our next function called path, look at all the inner bags, if we haven't already checked it already 
# go to this bag, check it for shiny gold.

def going_down_the_path(outer_bag,path):
    if 'shiny gold' in set_of_rules[outer_bag]: # Check the inner dictionary for shiny gold. If it's here, we've found it!
        return True
    else:
        for inner_bag in set_of_rules[outer_bag]: 
            if inner_bag not in path: # This means we haven't checked this bag for shiny gold yet.
                path.append(inner_bag) # Adds to path so that it won't run the below function again in the future for the same color.
                if going_down_the_path(inner_bag,path):
                    return True
        return False # This bag doesn't contain shiny gold.

# %%
def traverse_part1():
    count = 0
    for outer_bag in set_of_rules:
        path = []
        if going_down_the_path(outer_bag,path):
            count +=1
    print(f'The number of bag colors that can eventually contain at least one shiny gold bag is {count}.')

# %%
# The answer to part 1.
traverse_part1()
# Out:
# The number of bag colors that can eventually contain at least one shiny gold bag is 185.

# %% [markdown]
# ## Part Two
# It's getting pretty expensive to fly these days - not because of ticket prices, but because of the ridiculous number of bags you need to buy!
#
# Consider again your shiny gold bag and the rules from the above example:
#
# ```
# faded blue bags contain 0 other bags.
# dotted black bags contain 0 other bags.
# vibrant plum bags contain 11 other bags: 5 faded blue bags and 6 dotted black bags.
# dark olive bags contain 7 other bags: 3 faded blue bags and 4 dotted black bags.
# ```
#
# So, a single shiny gold bag must contain 1 dark olive bag (and the 7 bags within it) plus 2 vibrant plum bags (and the 11 bags within each of those):
#  1 + 1*7 + 2 + 2*11 = 32 bags!
#
# Of course, the actual rules have a small chance of going several levels deeper than this example; be sure to count all of the bags,
# even if the nesting becomes topologically impractical!
#
# Here's another example:
#
# ```
# shiny gold bags contain 2 dark red bags.
# dark red bags contain 2 dark orange bags.
# dark orange bags contain 2 dark yellow bags.
# dark yellow bags contain 2 dark green bags.
# dark green bags contain 2 dark blue bags.
# dark blue bags contain 2 dark violet bags.
# dark violet bags contain no other bags.
# ```
# In this example, a single shiny gold bag must contain 126 other bags.
#
# How many individual bags are required inside your single shiny gold bag?

# %%
# More recursion here. We're starting with the shiny gold bag as our outer bag. We'll begin with a counter of 0. The trivial case is if 
# there are no bags in the left. Otherwise, we'll go to each inner bag, and count how many of them there are and add to the count. Next we'll 
# want to run  this function again on the inner bag and multiply this number by the amount of bags we found. 

def count_bags(outer_bag):
    count = 0
    if set_of_rules[outer_bag] is bool:
        return 0
    else:
        # Go to each bag inside of the shiny gold bag
        for inner_bag in set_of_rules[outer_bag]:
            # Count the number of bags inside the bag
            count += set_of_rules[outer_bag][inner_bag]
            # The recursion part. Repeat the process for the inner bag.
            count += set_of_rules[outer_bag][inner_bag] * count_bags(inner_bag)
        return count

# %%
# The answer to part 2.
count_bags('shiny gold')
# Out:
# 89084

# %% [markdown]
# ## Moving Forward:
#
# Since I'm using notebooks, I think it'd be a useful exercise to run the code of people who implemented their solutions better than I did, so I can learn what to
# if I'm in a similar situation next time.
#
# -  Here's a neat solution using them from the [Reddit thread](https://www.reddit.com/r/adventofcode/comments/k8a31f/2020_day_07_solutions/?sort=top).
#     - Emanuele had suggested DAGs. This user (u/paraboul) implemented them with the `networkx` library.
#     - Their regex is slightly better too.
#     - I should look and mess with the visuals if I can make time.

# %%
import re
import networkx as nx

with open("data/day7_input.txt", "r") as fp:
    data = fp.readlines()


G = nx.DiGraph()

for line in data:
    m = re.match(r"(.*) bags contain (.*)$", line)
    if m:
        color = m.group(1)
        remain = m.group(2)

        for child in re.findall(r"([\d]+) (.*?) bag", remain):
            G.add_edge(color, child[1], count=int(child[0]))


def countBagsIn(root):
    totalBags = 0
    for k, val in G[root].items():
        totalBags += val['count'] * countBagsIn(k) + val['count']

    return totalBags

print(len(nx.ancestors(G, "shiny gold")))
print(countBagsIn('shiny gold'))
# Out:
# 185
# 89084
